# %% [markdown]
# # Here 'Hour' variable was considered while performing the Dirichlet Regression : (Y ~ Total_Value + Hour)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Output after performing Dirichlet Regression

# %%
dout = pd.read_csv('DirichletOutput.csv')
dout
# Out:
#      Ventilation  Sokets_Plug  Lighting  Other_Electricity   Cooling   Heating
# 0       0.245000     0.184258  0.147077           0.096283  0.229719  0.097662
# 1       0.178059     0.212094  0.148137           0.169019  0.175089  0.117601
# 2       0.184466     0.215909  0.153474           0.161512  0.167997  0.116642
# 3       0.191262     0.236375  0.174067           0.153194  0.128888  0.116214
# 4       0.165644     0.263540  0.189971           0.176932  0.083880  0.120033
# ..           ...          ...       ...                ...       ...       ...
# 139     0.280049     0.110660  0.098054           0.043747  0.402836  0.064653
# 140     0.304325     0.122127  0.111716           0.042684  0.352569  0.066579
# 141     0.314246     0.126947  0.117721           0.042087  0.331815  0.067184
# 142     0.261998     0.102390  0.088685           0.044201  0.439871  0.062854
# 143     0.265642     0.104044  0.090529           0.044131  0.432413  0.063241
#
# [144 rows x 6 columns]

# %% [markdown]
# # Loading test data

# %%
dtest = pd.read_csv('DirichletTest.csv# Output after performing Dirichlet Regression')
dtest
# Out:
#      Ventilation  Sokets_Plug  Lighting  Other_Electricity   Cooling   Heating
# 0       0.282631     0.123812  0.175766           0.325378  0.053112  0.039301
# 1       0.210534     0.104350  0.037804           0.528344  0.081917  0.037051
# 2       0.082739     0.120019  0.083448           0.518778  0.117903  0.077113
# 3       0.081094     0.151807  0.088780           0.359334  0.234818  0.084168
# 4       0.081675     0.229292  0.126408           0.001157  0.408221  0.153247
# ..           ...          ...       ...                ...       ...       ...
# 139     0.257588     0.069891  0.046289           0.001157  0.605789  0.019285
# 140     0.257588     0.069891  0.046289           0.001157  0.605789  0.019285
# 141     0.257588     0.069891  0.046289           0.001157  0.605789  0.019285
# 142     0.257588     0.069891  0.046289           0.001157  0.605789  0.019285
# 143     0.257588     0.069891  0.046289           0.001157  0.605789  0.019285
#
# [144 rows x 6 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Image, display

mpl.rcParams['figure.figsize'] = (20,15)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for VENTILATION

# %%
vent_out = dout['Ventilation']
vent_out = np.asarray(vent_out).reshape(-1)
vent_test = dtest['Ventilation']
vent_test = np.asarray(vent_test).reshape(-1)

# %%
plt.plot(vent_out, label='Predicted Value') #plot the loss
plt.plot(vent_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Ventillation Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Ventillation Prediction')

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for SOCKET PLUGS

# %%
socplug_out = dout['Sokets_Plug']
socplug_out = np.asarray(socplug_out).reshape(-1)
socplug_test = dtest['Sokets_Plug']
socplug_test = np.asarray(socplug_test).reshape(-1)

# %%
plt.plot(socplug_out, label='Predicted Value') #plot the loss
plt.plot(socplug_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Socket Plugs Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Socket Plugs Prediction')

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for LIGHTING

# %%
light_out = dout['Lighting']
light_out = np.asarray(light_out).reshape(-1)
light_test = dtest['Lighting']
light_test = np.asarray(light_test).reshape(-1)

# %%
plt.plot(light_out, label='Predicted Value') #plot the loss
plt.plot(light_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Lighting Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Lighting Prediction')

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for OTHER ELECTRICITY

# %%
elec_out = dout['Other_Electricity']
elec_out = np.asarray(elec_out).reshape(-1)
elec_test = dtest['Other_Electricity']
elec_test = np.asarray(elec_test).reshape(-1)

# %%
plt.plot(elec_out, label='Predicted Value') #plot the loss
plt.plot(elec_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Other Electricity Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Other Electricity Prediction')

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for COOLING

# %%
cool_out = dout['Cooling']
cool_out = np.asarray(cool_out).reshape(-1)
cool_test = dtest['Cooling']
cool_test = np.asarray(cool_test).reshape(-1)

# %%
plt.plot(cool_out, label='Predicted Value') #plot the loss
plt.plot(cool_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Cooling Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Cooling Prediction')

# %% [markdown]
# # Analyzing Dirichlet Regression Output with the test value for HEATING

# %%
heat_out = dout['Heating']
heat_out = np.asarray(heat_out).reshape(-1)
heat_test = dtest['Heating']
heat_test = np.asarray(heat_test).reshape(-1)

# %%
plt.plot(heat_out, label='Predicted Value') #plot the loss
plt.plot(heat_test, label='True Value') #plot the validation loss
plt.legend(['Predicted Value', 'True Value'], loc='upper right')
plt.title('Graph for Heating Prediction')
# Out:
# Text(0.5, 1.0, 'Graph for Heating Prediction')
